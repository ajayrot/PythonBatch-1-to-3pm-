# %% [markdown]
# # Example1:

# %%
import pandas as pd
dataset = pd.read_csv('stockprice_data.csv')#give the name of file bcz file is in same folder
dataset
# Out:
#          Date  Closing price    Return
# 0    1/1/2020            100  0.010000
# 1    2/1/2020            120  0.200000
# 2    3/1/2020            130  0.083333
# 3    4/1/2020             98 -0.246154
# 4    5/1/2020             50 -0.489796
# 5    6/1/2020            102  1.040000
# 6    7/1/2020            104  0.019608
# 7    8/1/2020            150  0.442308
# 8    9/1/2020            160  0.066667
# 9   10/1/2020            109 -0.318750
# 10  11/1/2020             95 -0.128440

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# convert pandas data frame into pandas series
data3 = dataset.iloc[0:]
data3
# Out:
#          Date  Closing price    Return
# 0    1/1/2020            100  0.010000
# 1    2/1/2020            120  0.200000
# 2    3/1/2020            130  0.083333
# 3    4/1/2020             98 -0.246154
# 4    5/1/2020             50 -0.489796
# 5    6/1/2020            102  1.040000
# 6    7/1/2020            104  0.019608
# 7    8/1/2020            150  0.442308
# 8    9/1/2020            160  0.066667
# 9   10/1/2020            109 -0.318750
# 10  11/1/2020             95 -0.128440

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Example2:

# %%
import pandas as pd
data = pd.read_csv('automobile_data.csv')
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
data1 = data.iloc[0:]
data1
# Out:
# 0     0.010000
# 1     0.200000
# 2     0.083333
# 3    -0.246154
# 4    -0.489796
# 5     1.040000
# 6     0.019608
# 7     0.442308
# 8     0.066667
# 9    -0.318750
# 10   -0.128440
# Name: Return, dtype: float64

# %%
type(data1)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
dataset = pd.read_csv('stockprice_data.csv')#give the name of file bcz file is in same folder
dataset
# Out:
#          Date  Closing price    Return
# 0    1/1/2020            100  0.010000
# 1    2/1/2020            120  0.200000
# 2    3/1/2020            130  0.083333
# 3    4/1/2020             98 -0.246154
# 4    5/1/2020             50 -0.489796
# 5    6/1/2020            102  1.040000
# 6    7/1/2020            104  0.019608
# 7    8/1/2020            150  0.442308
# 8    9/1/2020            160  0.066667
# 9   10/1/2020            109 -0.318750
# 10  11/1/2020             95 -0.128440

# %%
# head() method
#tail() method
print(dataset.head(5))
print(dataset.tail(5))
# Out:
#        Date  Closing price    Return
# 0  1/1/2020            100  0.010000
# 1  2/1/2020            120  0.200000
# 2  3/1/2020            130  0.083333
# 3  4/1/2020             98 -0.246154
# 4  5/1/2020             50 -0.489796
#          Date  Closing price    Return
# 6    7/1/2020            104  0.019608
# 7    8/1/2020            150  0.442308
# 8    9/1/2020            160  0.066667
# 9   10/1/2020            109 -0.318750
# 10  11/1/2020             95 -0.128440

# %%
print(dataset.loc[4:8])
# Out:
#        Date  Closing price    Return
# 4  5/1/2020             50 -0.489796
# 5  6/1/2020            102  1.040000
# 6  7/1/2020            104  0.019608
# 7  8/1/2020            150  0.442308
# 8  9/1/2020            160  0.066667

# %%
#to update particular row value 
dataset.loc[4 , 'Closing price'] = 150

# %%
dataset
# Out:
#          Date  Closing price    Return
# 0    1/1/2020            100  0.010000
# 1    2/1/2020            120  0.200000
# 2    3/1/2020            130  0.083333
# 3    4/1/2020             98 -0.246154
# 4    5/1/2020            150 -0.489796
# 5    6/1/2020            102  1.040000
# 6    7/1/2020            104  0.019608
# 7    8/1/2020            150  0.442308
# 8    9/1/2020            160  0.066667
# 9   10/1/2020            109 -0.318750
# 10  11/1/2020             95 -0.128440

# %%
import pandas as pd
data = pd.read_csv('automobile_data.csv')
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
#Plotting
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('automobile_data.csv')
data.plot(kind = 'scatter', x = 'horsepower' , y = 'price')
plt.show()

# %% [markdown]
# # Introduction:
# - machine learning and artificial intelligence will use in data science
# # Live Applications of AI:
# - Google Search Engine will get perdictive searches.
# - Google AI Eye Dcotor
# - Twitter

# %% [markdown]
# # Types of AI:
# - Artificial Narrow Intelligence
# - Artificial General Intelligence
# - Aritificial Super Intelligence

# %% [markdown]
# # ANI:
# - weak ai invloves and appyinh only to specific tasks
# **Example:** - Alexa
# # AGI:
# - Strong Ai and it invloues to perform any intellectual task that a human can be.
# **Example:** - chess game
# # ASI:

# %% [markdown]
# # Introduction to Machine Learning:
# - Machine learning is used in AI
# - Ml is way in which you feed a lot of data to a machine so that it can make its own decisions.

# %% [markdown]
# # Types of machine learning:
# - Supervised learning
# - Unsupervised learning
# - reinforcement learning
# # Types of Problem Solved using Ml
# - Regression
# - Classification
# - Clstering
# # Steps to follow in machine leaning while Problem Solving
# - Step1:Define the object of problem
#         - to perdict the possibility of rain by stuying weather condition
# - Step2:Data Gathering:
#         - Data such as weather condition,humidity level,Temperature,Pressure
# - Step3:Prepare Data
# - Step4:Data Analysis
# - Step5:Bulid A ML Model
# - Step6:Model Evaluation and Optimization
# - Step7:Predict
